# %%
import warnings

from configs import cfg
from data import load
from data.preprocessing import Encoders, Scalers
from eda.bank_analyser import BankAnalyzer
from eda.bank_plot import BankPlots

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
bank = load(cfg)
bank.load_dataset()

encoder = Encoders(cdg=cfg)
scaler = Scalers(cfg=cfg)

analyzer = BankAnalyzer(dataset=bank, cfg=cfg)
plots = BankPlots(dataset=bank, cfg=cfg)

# %% [markdown]
# # General Overview

# %%
analyzer.description()
# Out:
# --------------- about dataset  -----------------
# Input variables:
#    # bank client data:
#    1 - age (numeric)
#    2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
#                                        "blue-collar","self-employed","retired","technician","services")
#    3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#    4 - education (categorical: "unknown","secondary","primary","tertiary")
#    5 - default: has credit in default? (binary: "yes","no")
#    6 - balance: average yearly balance, in euros (numeric)
#    7 - housing: has housing loan? (binary: "yes","no")
#    8 - loan: has personal loan? (binary: "yes","no")
#    # related with the last contact of the current campaign:
#    9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
#   10 - day: last contact day of the month (numeric)
#   11 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#   12 - duration: last contact duration, in seconds (numeric)
#    # other attributes:
#   13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#   14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#   15 - previous: number of contacts performed before this campaign and for this client (numeric)
#   16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
#   Output variable (desired target):
#   17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
#
#
# --------------- description.txt ----------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB
# None
#
#
# --------------- description.txt ----------------
#            count         mean          std     min    25%    50%     75%  \
# age       4521.0    41.170095    10.576211    19.0   33.0   39.0    49.0
# balance   4521.0  1422.657819  3009.638142 -3313.0   69.0  444.0  1480.0
# day       4521.0    15.915284     8.247667     1.0    9.0   16.0    21.0
# duration  4521.0   263.961292   259.856633     4.0  104.0  185.0   329.0
# campaign  4521.0     2.793630     3.109807     1.0    1.0    2.0     3.0
# pdays     4521.0    39.766645   100.121124    -1.0   -1.0   -1.0    -1.0
# previous  4521.0     0.542579     1.693562     0.0    0.0    0.0     0.0
#
#               max
# age          87.0
# balance   71188.0
# day          31.0
# duration   3025.0
# campaign     50.0
# pdays       871.0
# previous     25.0
#
#
# --------------- nan Values -----------------
#            Total  Percent
# y              0      0.0
# loan           0      0.0
# job            0      0.0
# marital        0      0.0
# education      0      0.0
# default        0      0.0
# balance        0      0.0
# housing        0      0.0
# contact        0      0.0
# poutcome       0      0.0
# day            0      0.0
# month          0      0.0
# duration       0      0.0
# campaign       0      0.0
# pdays          0      0.0
# previous       0      0.0
# age            0      0.0
#
#
# --------------- duplicates -----------------
# Total number of duplicates:  0
#
#
# ------ Numerical/Categorical Features ------
# Numerical Features: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
# number of Numerical Features: 7
# Categorical Features: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']
# number of Categorical Features: 10
#
#
# --------------- skew & kurt -----------------
# calculate skewness and kurtosis of numerical features
#               skew  skew log  skew sqrt  skew box cox        kurt  kurt log  \
# balance   6.596431  1.886529   2.568352       3.455312  88.390332  4.504575
# previous  5.875259  1.770750   2.423893       3.116057  51.995212  3.989627
# campaign  4.743914  1.556863   2.178053       2.546934  37.168920  3.668892
# duration  2.772420  1.019720   1.665058       1.396754  12.530050  2.678936
# pdays     2.717071  0.999555   1.648354       1.360248   7.957128  2.302251
# age       0.699501 -0.357387   0.836362      -0.322345   0.348775  0.870585
# day       0.094627 -2.357813   0.307615      -1.275783  -1.039531  0.000000
#
#           kurt sqrt  kurt box cox
# balance    9.509462      7.100710
# previous   7.350833      5.952264
# campaign   6.261665      5.291365
# duration   3.817012      3.486498
# pdays      3.161749      2.883594
# age        1.545415      0.946204
# day        1.000000      0.000000
#
#
# ----------------- quantiles -----------------
#           0.10   0.25   0.50    0.75
# age       29.0   33.0   39.0    49.0
# balance    0.0   69.0  444.0  1480.0
# day        5.0    9.0   16.0    21.0
# duration  58.0  104.0  185.0   329.0
# campaign   1.0    1.0    2.0     3.0
# pdays     -1.0   -1.0   -1.0    -1.0
# previous   0.0    0.0    0.0     0.0
#
#
# ----------------- is target balanced? -----------------
#   value  counts
# 0    no    4000
# 1   yes     521

# %% [markdown]
# # Age

# %%
analyzer.age()
# Out:
# --------------- nan Values of age -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of age -----------------
# Total number of duplicates:  4454
#
#
# --------------- skew & kurt of age -----------------
# calculate skewness and kurtosis of numerical features
# {'skew': 0.6995014533559305, 'kurt': 0.3487754872611486}
#
#
# --------------- quantiles of age -----------------
#    quantile  values
# 0      0.10    29.0
# 1      0.25    33.0
# 2      0.50    39.0
# 3      0.75    49.0
#
#
# ----------------- Top 15 values in column of age -----------------
#     value  counts
# 0      34     231
# 1      32     224
# 2      31     199
# 3      36     188
# 4      33     186
# 5      35     180
# 6      37     161
# 7      38     159
# 8      30     150
# 9      40     142
# 10     42     141
# 11     41     135
# 12     39     130
# 13     46     119
# 14     43     115

# %%
plots.age()

# %% [markdown]
# # Job

# %%
analyzer.job()
# Out:
# --------------- nan Values of job -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of job -----------------
# Total number of duplicates:  4509
#
#
# --------------- skew & kurt of job -----------------
# calculate skewness and kurtosis of numerical features
# job is categorical feature
#
#
# --------------- quantiles of job -----------------
# job is categorical feature
#
#
# ----------------- Top 15 values in column of job -----------------
#             value  counts
# 0      management     969
# 1     blue-collar     946
# 2      technician     768
# 3          admin.     478
# 4        services     417
# 5         retired     230
# 6   self-employed     183
# 7    entrepreneur     168
# 8      unemployed     128
# 9       housemaid     112
# 10        student      84
# 11        unknown      38

# %%
plots.job()

# %% [markdown]
# # marital

# %%
analyzer.marital()
# Out:
# --------------- nan Values of marital -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of marital -----------------
# Total number of duplicates:  4518
#
#
# --------------- skew & kurt of marital -----------------
# calculate skewness and kurtosis of numerical features
# marital is categorical feature
#
#
# --------------- quantiles of marital -----------------
# marital is categorical feature
#
#
# ----------------- Top 15 values in column of marital -----------------
#       value  counts
# 0   married    2797
# 1    single    1196
# 2  divorced     528

# %%
plots.marital()

# %% [markdown]
# # education

# %%
analyzer.education()
# Out:
# --------------- nan Values of education -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of education -----------------
# Total number of duplicates:  4517
#
#
# --------------- skew & kurt of education -----------------
# calculate skewness and kurtosis of numerical features
# education is categorical feature
#
#
# --------------- quantiles of education -----------------
# education is categorical feature
#
#
# ----------------- Top 15 values in column of education -----------------
#        value  counts
# 0  secondary    2306
# 1   tertiary    1350
# 2    primary     678
# 3    unknown     187
#
#
# Pivot age/education (min)
# education  y
# primary    no      614
#            yes      64
# secondary  no     2061
#            yes     245
# tertiary   no     1157
#            yes     193
# unknown    no      168
#            yes      19
# dtype: int64
#
# Pivot age/education (min)
#           age
# y          no yes
# education
# primary    23  19
# secondary  20  19
# tertiary   22  22
# unknown    19  34
#
# Pivot age/education (max)
#           age
# y          no yes
# education
# primary    83  87
# secondary  86  80
# tertiary   78  77
# unknown    79  73
#
# Pivot age/education (mean)
#                  age
# y                 no        yes
# education
# primary    46.276873  52.171875
# secondary  39.895197  41.469388
# tertiary   39.632671  39.725389
# unknown    44.636905  51.157895

# %%
plots.education()

# %% [markdown]
# # default

# %%
analyzer.default()
# Out:
# --------------- nan Values of default -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of default -----------------
# Total number of duplicates:  4519
#
#
# --------------- skew & kurt of default -----------------
# calculate skewness and kurtosis of numerical features
# default is categorical feature
#
#
# --------------- quantiles of default -----------------
# default is categorical feature
#
#
# ----------------- Top 15 values in column of default -----------------
#   value  counts
# 0    no    4445
# 1   yes      76

# %%
plots.default()

# %% [markdown]
# # balance

# %%
analyzer.balance()
# Out:
# --------------- nan Values of balance -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of balance -----------------
# Total number of duplicates:  2168
#
#
# --------------- skew & kurt of balance -----------------
# calculate skewness and kurtosis of numerical features
# {'skew': 6.596430546295735, 'kurt': 88.39033211861796}
#
#
# --------------- quantiles of balance -----------------
#    quantile  values
# 0      0.10     0.0
# 1      0.25    69.0
# 2      0.50   444.0
# 3      0.75  1480.0
#
#
# ----------------- Top 15 values in column of balance -----------------
#     value  counts
# 0       0     357
# 1       2      24
# 2       1      15
# 3       4      13
# 4      23      11
# 5       5      11
# 6     179      10
# 7       6      10
# 8      14      10
# 9      35      10
# 10     50       9
# 11    174       9
# 12      8       9
# 13     60       9
# 14     25       9

# %%
plots.balance()

# %% [markdown]
# # housing

# %%
analyzer.housing()
# Out:
# --------------- nan Values of housing -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of housing -----------------
# Total number of duplicates:  4519
#
#
# --------------- skew & kurt of housing -----------------
# calculate skewness and kurtosis of numerical features
# housing is categorical feature
#
#
# --------------- quantiles of housing -----------------
# housing is categorical feature
#
#
# ----------------- Top 15 values in column of housing -----------------
#   value  counts
# 0   yes    2559
# 1    no    1962

# %%
plots.housing()

# %% [markdown]
# # loan

# %%
analyzer.loan()
# Out:
# --------------- nan Values of loan -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of loan -----------------
# Total number of duplicates:  4519
#
#
# --------------- skew & kurt of loan -----------------
# calculate skewness and kurtosis of numerical features
# loan is categorical feature
#
#
# --------------- quantiles of loan -----------------
# loan is categorical feature
#
#
# ----------------- Top 15 values in column of loan -----------------
#   value  counts
# 0    no    3830
# 1   yes     691

# %%
plots.loan()

# %% [markdown]
# # contact

# %%
analyzer.contact()
# Out:
# --------------- nan Values of contact -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of contact -----------------
# Total number of duplicates:  4518
#
#
# --------------- skew & kurt of contact -----------------
# calculate skewness and kurtosis of numerical features
# contact is categorical feature
#
#
# --------------- quantiles of contact -----------------
# contact is categorical feature
#
#
# ----------------- Top 15 values in column of contact -----------------
#        value  counts
# 0   cellular    2896
# 1    unknown    1324
# 2  telephone     301

# %%
plots.contact()

# %% [markdown]
# # day

# %%
analyzer.day()
# Out:
# --------------- nan Values of day -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of day -----------------
# Total number of duplicates:  4490
#
#
# --------------- skew & kurt of day -----------------
# calculate skewness and kurtosis of numerical features
# {'skew': 0.09462690455175846, 'kurt': -1.0395310625320089}
#
#
# --------------- quantiles of day -----------------
#    quantile  values
# 0      0.10     5.0
# 1      0.25     9.0
# 2      0.50    16.0
# 3      0.75    21.0
#
#
# ----------------- Top 15 values in column of day -----------------
#     value  counts
# 0      20     257
# 1      18     226
# 2      19     201
# 3      21     198
# 4      14     195
# 5      17     191
# 6       7     190
# 7       6     187
# 8      28     181
# 9       5     181
# 10      8     180
# 11     29     175
# 12     15     174
# 13     30     168
# 14     13     166

# %%
plots.day()

# %% [markdown]
# # month

# %%
analyzer.month()
# Out:
# --------------- nan Values of month -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of month -----------------
# Total number of duplicates:  4509
#
#
# --------------- skew & kurt of month -----------------
# calculate skewness and kurtosis of numerical features
# month is categorical feature
#
#
# --------------- quantiles of month -----------------
# month is categorical feature
#
#
# ----------------- Top 15 values in column of month -----------------
#    value  counts
# 0    may    1398
# 1    jul     706
# 2    aug     633
# 3    jun     531
# 4    nov     389
# 5    apr     293
# 6    feb     222
# 7    jan     148
# 8    oct      80
# 9    sep      52
# 10   mar      49
# 11   dec      20

# %%
plots.month()

# %% [markdown]
# # duration

# %%
analyzer.duration()
# Out:
# --------------- nan Values of duration -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of duration -----------------
# Total number of duplicates:  3646
#
#
# --------------- skew & kurt of duration -----------------
# calculate skewness and kurtosis of numerical features
# {'skew': 2.7724197169136455, 'kurt': 12.530049737749446}
#
#
# --------------- quantiles of duration -----------------
#    quantile  values
# 0      0.10    58.0
# 1      0.25   104.0
# 2      0.50   185.0
# 3      0.75   329.0
#
#
# ----------------- Top 15 values in column of duration -----------------
#     value  counts
# 0     123      27
# 1     104      25
# 2     119      23
# 3     106      22
# 4      77      22
# 5     121      22
# 6      58      22
# 7      71      20
# 8     168      20
# 9     127      19
# 10     97      19
# 11     76      19
# 12     89      19
# 13    113      19
# 14    151      19

# %%
plots.duration()

# %% [markdown]
# # campaign

# %%
analyzer.campaign()
# Out:
# --------------- nan Values of campaign -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of campaign -----------------
# Total number of duplicates:  4489
#
#
# --------------- skew & kurt of campaign -----------------
# calculate skewness and kurtosis of numerical features
# {'skew': 4.74391446894159, 'kurt': 37.168920102993624}
#
#
# --------------- quantiles of campaign -----------------
#    quantile  values
# 0      0.10     1.0
# 1      0.25     1.0
# 2      0.50     2.0
# 3      0.75     3.0
#
#
# ----------------- Top 15 values in column of campaign -----------------
#     value  counts
# 0       1    1734
# 1       2    1264
# 2       3     558
# 3       4     325
# 4       5     167
# 5       6     155
# 6       7      75
# 7       8      56
# 8       9      30
# 9      10      27
# 10     11      22
# 11     12      21
# 12     13      17
# 13     14      10
# 14     15       9

# %%
plots.campaign()

# %% [markdown]
# # pdays

# %%
analyzer.pdays()
# Out:
# --------------- nan Values of pdays -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of pdays -----------------
# Total number of duplicates:  4229
#
#
# --------------- skew & kurt of pdays -----------------
# calculate skewness and kurtosis of numerical features
# {'skew': 2.71707136656418, 'kurt': 7.957127901823425}
#
#
# --------------- quantiles of pdays -----------------
#    quantile  values
# 0      0.10    -1.0
# 1      0.25    -1.0
# 2      0.50    -1.0
# 3      0.75    -1.0
#
#
# ----------------- Top 15 values in column of pdays -----------------
#     value  counts
# 0      -1    3705
# 1     182      23
# 2     183      20
# 3     363      12
# 4      92      12
# 5      91      11
# 6     169      10
# 7     181      10
# 8     370       9
# 9     364       9
# 10     99       8
# 11     94       8
# 12    167       8
# 13    349       8
# 14    184       7

# %%
plots.pdays()

# %% [markdown]
# # previous

# %%
analyzer.previous()
# Out:
# --------------- nan Values of previous -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of previous -----------------
# Total number of duplicates:  4497
#
#
# --------------- skew & kurt of previous -----------------
# calculate skewness and kurtosis of numerical features
# {'skew': 5.875258677896706, 'kurt': 51.995211518308764}
#
#
# --------------- quantiles of previous -----------------
#    quantile  values
# 0      0.10     0.0
# 1      0.25     0.0
# 2      0.50     0.0
# 3      0.75     0.0
#
#
# ----------------- Top 15 values in column of previous -----------------
#     value  counts
# 0       0    3705
# 1       1     286
# 2       2     193
# 3       3     113
# 4       4      78
# 5       5      47
# 6       6      25
# 7       7      22
# 8       8      18
# 9       9      10
# 10     12       5
# 11     10       4
# 12     11       3
# 13     14       2
# 14     15       1

# %%
plots.previous()

# %% [markdown]
# # poutcome

# %%
analyzer.poutcome()
# Out:
# --------------- nan Values of poutcome -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of poutcome -----------------
# Total number of duplicates:  4517
#
#
# --------------- skew & kurt of poutcome -----------------
# calculate skewness and kurtosis of numerical features
# poutcome is categorical feature
#
#
# --------------- quantiles of poutcome -----------------
# poutcome is categorical feature
#
#
# ----------------- Top 15 values in column of poutcome -----------------
#      value  counts
# 0  unknown    3705
# 1  failure     490
# 2    other     197
# 3  success     129

# %%
plots.poutcome()

# %% [markdown]
# # y

# %%
analyzer.y()
# Out:
# --------------- nan Values of y -----------------
# {'total': 0, 'percentage': 0.0}
#
#
# --------------- duplicates of y -----------------
# Total number of duplicates:  4519
#
#
# --------------- skew & kurt of y -----------------
# calculate skewness and kurtosis of numerical features
# y is categorical feature
#
#
# --------------- quantiles of y -----------------
# y is categorical feature
#
#
# ----------------- Top 15 values in column of y -----------------
#   value  counts
# 0    no    4000
# 1   yes     521

# %%
plots.y()
